# %% [markdown]
# # Predicting Price Using Regression
#
# In this notebook we will be working on the data set on houses from King's county. The **aim** of the notebook is to build a linear regression model which can help us predict sales price of houses in King's county. During the process we hope to find interesting relationship between different variables and select features that are most predictive utility.
#
# In order to begin analysis, the first thing we need to do is to set up our system by importing the appropriate libraries and the dataset we will be using.

# %%
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
import folium
from folium.plugins import HeatMap
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
np.random.seed(0)


df = pd.read_csv('kc_house_data.csv')

# %%
print("King's county data set has {} rows and {} columns".format(df.shape[0], df.shape[1]))
df.sample(10)
# Out:
# King's county data set has 21597 rows and 21 columns
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 156    6388930390  11/20/2014  650000.0         5       3.50         3960
# 15572  2128000050   8/15/2014  625000.0         4       2.25         2070
# 2080   4401200350   2/10/2015  822500.0         3       2.50         3090
# 17522  3356402232   9/24/2014  179900.0         3       1.75         1230
# 8360   2212600100   5/22/2014  370000.0         4       2.75         3150
# 12832  9430110120    5/5/2015  737000.0         3       2.50         2300
# 17280  5126310470   1/15/2015  515500.0         4       2.75         2830
# 7583   8121100147   7/14/2014  390000.0         3       2.25         1640
# 19963  1085623710   7/14/2014  447055.0         4       2.50         2448
# 1754   3295610350   3/23/2015  850000.0         5       2.75         3430
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 156       25245     2.0         0.0   0.0  ...      9        2500
# 15572      7200     1.0         0.0   0.0  ...      8        1390
# 2080       7708     2.0         0.0   0.0  ...     10        3090
# 17522     12000     1.0         NaN   0.0  ...      6        1230
# 8360      67518     1.0         NaN   0.0  ...      9        2250
# 12832      7800     2.0         0.0   2.0  ...      9        2300
# 17280      8126     2.0         0.0   0.0  ...      8        2830
# 7583       2875     2.0         0.0   0.0  ...      6        1240
# 19963      4949     2.0         0.0   0.0  ...      9        2448
# 1754      15119     2.0         0.0   0.0  ...     10        3430
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 156           1460.0     1996           0.0    98056  47.5250 -122.172
# 15572          680.0     1977           0.0    98033  47.6970 -122.169
# 2080             0.0     1999           0.0    98052  47.6868 -122.108
# 17522            0.0     1970           0.0    98001  47.2878 -122.251
# 8360           900.0     1965           0.0    98092  47.3382 -122.196
# 12832            0.0     1997           0.0    98052  47.6842 -122.155
# 17280            0.0     2005           NaN    98059  47.4863 -122.140
# 7583           400.0     1983           0.0    98118  47.5686 -122.286
# 19963            0.0     2014           0.0    98030  47.3428 -122.179
# 1754             0.0     1998           0.0    98075  47.5678 -122.032
#
#        sqft_living15  sqft_lot15
# 156             2640       13675
# 15572           2110        8400
# 2080            3140        8592
# 17522           1550       12000
# 8360            2210       32391
# 12832           2300        8187
# 17280           2830        7916
# 7583            1500        3960
# 19963           2815        5446
# 1754            3430       12045
#
# [10 rows x 21 columns]

# %% [markdown]
# In order to build our model we need to first understand our dataset and the variables that compose them. This dataset has 21597 observation and 21 columns. Out of these the ID has no predictive utility and so we have 19 variables to work with. The data dictionary provides the following information about them
#
# * **dateDate** - house was sold
# * **price** - Price is prediction target
# * **bedrooms** - Number of Bedrooms/House
# * **bathrooms** -  Number of bathrooms/bedrooms
# * **sqft_living** - square-footage of the home
# * **sqft_lots** - square-footage of the lot
# * **floorsTotal** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed
# * **condition** - How good the condition is ( Overall )
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors
#
# I have chosen to see a random sample from the dataset just so that I can be sure that the file was read correctly and to get an idea of what's going on with the data. It also helps me to check for any missing values in the dataset.
#
# Since I can see some missing values and '?' in the data I would like to carry out more analysis to see the datatype and number of non-null values. I would also like to get a summary of all of our variables.

# %%
df.info()
df[['price','sqft_living','sqft_lot']].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB
#               price   sqft_living      sqft_lot
# count  2.159700e+04  21597.000000  2.159700e+04
# mean   5.402966e+05   2080.321850  1.509941e+04
# std    3.673681e+05    918.106125  4.141264e+04
# min    7.800000e+04    370.000000  5.200000e+02
# 25%    3.220000e+05   1430.000000  5.040000e+03
# 50%    4.500000e+05   1910.000000  7.618000e+03
# 75%    6.450000e+05   2550.000000  1.068500e+04
# max    7.700000e+06  13540.000000  1.651359e+06

# %% [markdown]
# Of all of the columns I am more intuitively interested in the square footage are and lot size of the property. From first assumption it would seem that they would be a good indicator of what the property is worth as unlike bedrooms or bathrooms it ca't be changed easily without a substantial financial investment.
#
# Since our data set doesnt contain any missing values in the **'sqft_living'** column, and its datatype is alright, it also doesnt have any value starting from 0. So I would like to explore its relationship with price on its own before I make any changes to the data set during preprocessing.
#
# We will begin by first looking at the distribution of price and sqft_living before we plot and scatter plot to see their relationship.

# %%
# plotting a histogram of price data and plotting a normal probability plot
sns.distplot(df['price'], fit=norm);
fig = plt.figure()
plt.xticks(rotation=90);
res = stats.probplot(df['price'], plot=plt)

#skewness and kurtosis
print("Skewness: %f" % df['price'].skew())
print("Kurtosis: %f" % df['price'].kurt())
# Out:
# Skewness: 4.023365
# Kurtosis: 34.541359

# %%
# plotting a histogram of price data and plotting a normal probability plot
sns.distplot(df['sqft_living'], fit=norm);
fig = plt.figure()
plt.xticks(rotation=90);
res = stats.probplot(df['sqft_living'], plot=plt)

#skewness and kurtosis
print("Skewness: %f" % df['sqft_living'].skew())
print("Kurtosis: %f" % df['sqft_living'].kurt())
# Out:
# Skewness: 1.473215
# Kurtosis: 5.252102

# %% [markdown]
# We can note that both of the variables don't have a perfectly normal distribution, but they each have a positive skewness and show peakedness. Both are much higher in the price distribution. We may have to transform these variables to make them more normally distributed.
#
# Before we make any transformation I will create a subset of the data containing only the columns of interest. I will also be carrying out a scatter plot before we do any transformation just to check if they have any linear relationship.

# %%
# create a subset
df_1 = df[['price', 'sqft_living']]

# plot the scatter plot
plt.figure(figsize=(10,8))
df_1.plot.scatter('price','sqft_living')

# %% [markdown]
# It seems that they have a linear realtionship and so we can prepare to transform them and check how well they can be used to predict house prices.
#
# I will carry out the simple regression on both the original data and the normalized data to see if normalisig the variables had any major significance.

# %% [markdown]
# ### Normalising our variables.
#
# We notice that price of house is deviating a lot from normal, but we can fix it by doing a simple data transformation. From my reading I have found out that in case of positive skewness we can perform a log transformation of the values. It can be done quite simply in few steps.

# %%
# applying log transformation for both columns
df_1['normal_price'] = np.log(df_1['price'])
df_1['normal_sqft_living'] = np.log(df_1['sqft_living'])

# %%
#transformed histogram and normal probability plot
sns.distplot(df_1['normal_price'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_1['normal_price'], plot=plt)

#skewness and kurtosis
print("Skewness: %f" % df_1['normal_price'].skew())
print("Kurtosis: %f" % df_1['normal_price'].kurt())
# Out:
# Skewness: 0.431004
# Kurtosis: 0.691049

# %%
#transformed histogram and normal probability plot
sns.distplot(df_1['normal_sqft_living'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_1['normal_sqft_living'], plot=plt)

#skewness and kurtosis
print("Skewness: %f" % df_1['normal_sqft_living'].skew())
print("Kurtosis: %f" % df_1['normal_sqft_living'].kurt())
# Out:
# Skewness: -0.027362
# Kurtosis: -0.079038

# %% [markdown]
# Ok now that we transformed our data we can see that it shows signs of normal distribution with acceptable values for skewness and kurtosis.
#
# We can therefore start our first ordinary least square regression model using statsmodel.

# %%
import statsmodels.api as sm

X = df_1['sqft_living']
y = df_1['price']
# Setting up the LEARNER
X = sm.add_constant(X)
model_sm = sm.OLS(y,X)

# Actually LEARNING
results = model_sm.fit()

# Evaluating performance
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))

# # Understanding the LEARNED model
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.49
# const         -43988.8922
# sqft_living      280.8630
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.097e+04
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:45:40   Log-Likelihood:            -3.0006e+05
# No. Observations:               21597   AIC:                         6.001e+05
# Df Residuals:                   21595   BIC:                         6.001e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.399e+04   4410.023     -9.975      0.000   -5.26e+04   -3.53e+04
# sqft_living   280.8630      1.939    144.819      0.000     277.062     284.664
# ==============================================================================
# Omnibus:                    14801.942   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           542662.604
# Skew:                           2.820   Prob(JB):                         0.00
# Kurtosis:                      26.901   Cond. No.                     5.63e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels.api as sm

X = df_1['normal_sqft_living']
y = df_1['normal_price']
# Setting up the LEARNER
X = sm.add_constant(X)
model_sm = sm.OLS(y,X)

# Actually LEARNING
results = model_sm.fit()

# Evaluating performance
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))

# # Understanding the LEARNED model
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.46
# const                 6.7234
# normal_sqft_living    0.8376
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           normal_price   R-squared:                       0.455
# Model:                            OLS   Adj. R-squared:                  0.455
# Method:                 Least Squares   F-statistic:                 1.805e+04
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:45:45   Log-Likelihood:                -10231.
# No. Observations:               21597   AIC:                         2.047e+04
# Df Residuals:                   21595   BIC:                         2.048e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.7234      0.047    142.612      0.000       6.631       6.816
# normal_sqft_living     0.8376      0.006    134.368      0.000       0.825       0.850
# ==============================================================================
# Omnibus:                      123.577   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              114.096
# Skew:                           0.143   Prob(JB):                     1.68e-25
# Kurtosis:                       2.787   Cond. No.                         137.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Conclusions drawn from first analysis
#
# I also printed the intercept and coefficient for the ordinary least square linear regression. By using these values and the below definition, we can estimate the house prices manually. The equation we use for our estimations is called hypothesis function and defined as
#
# $$h_{\theta}(X)=\theta_{0}+\theta_{1}x$$
#
# Suprisingly by normalising the data we loose some of the predictive power afforded by sqft_living. We see that the r2 for orignal data is 0.493 but after normalising the data we get r2 of 0.455. Even though the difference is not a lot I would still prefer to work with original data for conveinience. For next stage of analysis we are going to ingnore normal data and perform all analysis only on the original price. Before we can begin that we will need to clean and process our data to get it ready for next stage of analysis.
#
# ## Second stage:
#
# From the initial summary information we obtained about our data we noticed that some columns had missing value. We will have to explore that further and in order to understand what we can do about those missing values we will carry out a correlation matrix. The correlation matrix would help us to identify and divert our attention only towards the important features of our data.

# %%
""" We need to first get a count of missing values in our dataset"""

# get the number of missing data points per column
df_miss = df.isnull().sum()

# look at the columns with more than 0 missing values
df_miss[df_miss > 0]
# Out:
# waterfront      2376
# view              63
# yr_renovated    3842
# dtype: int64

# %% [markdown]
# Only three columns have missing values, before we can approach to deal with the missing dataset I will chart a heatmap of correlation.

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmin= -1, vmax= 1, square=True);

# %% [markdown]
# We can see that there is many orange coloured squares showing relationship with price. The first one refers to 'bedrooms', 'bathrooms', sqft_living, grade, sqft_above. Actually, the correlation between these variables are so strong that it can indicate a situaton of multicollinearity. If we think about it most of these variables are conveying the same information.
#
# This heatmap shows too many variables, also many variables are categorical and so their correlation cannot be easily ascertained. Going further I will filter the heatmap to show only those variables which are most strongly correlated with price.

# %%
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'price')['price'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Before we can clearly see the correlation between variables we will create a new dataframe where missing values are dropped.

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
# **We create a new data frame and carry out cleaning and processing of variables to check for improvement in performance of linear regression model.**

# %%
df1 = df[(df['sqft_basement'] != '?')]

# %%
df1['bedrooms'] = df1['bedrooms'].astype('float64')
df1['sqft_basement'] = df1['sqft_basement'].astype('float64')

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21143 non-null int64
# date             21143 non-null object
# price            21143 non-null float64
# bedrooms         21143 non-null float64
# bathrooms        21143 non-null float64
# sqft_living      21143 non-null int64
# sqft_lot         21143 non-null int64
# floors           21143 non-null float64
# waterfront       18804 non-null float64
# view             21082 non-null float64
# condition        21143 non-null int64
# grade            21143 non-null int64
# sqft_above       21143 non-null int64
# sqft_basement    21143 non-null float64
# yr_built         21143 non-null int64
# yr_renovated     17389 non-null float64
# zipcode          21143 non-null int64
# lat              21143 non-null float64
# long             21143 non-null float64
# sqft_living15    21143 non-null int64
# sqft_lot15       21143 non-null int64
# dtypes: float64(10), int64(10), object(1)
# memory usage: 3.5+ MB

# %%
df1['year_sold'] = df1['date'].map(lambda x: x[-4:])
df1['year_sold'] = df1['year_sold'].astype('int64')

# %%
df1 = df1.assign(age = lambda x: x['year_sold'] - x['yr_built'])
df1.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0       3.0       1.00         1180
# 1  6414100192   12/9/2014  538000.0       3.0       2.25         2570
# 2  5631500400   2/25/2015  180000.0       2.0       1.00          770
# 3  2487200875   12/9/2014  604000.0       4.0       3.00         1960
# 4  1954400510   2/18/2015  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0         NaN   0.0  ...            0.0      1955
# 1      7242     2.0         0.0   0.0  ...          400.0      1951
# 2     10000     1.0         0.0   0.0  ...            0.0      1933
# 3      5000     1.0         0.0   0.0  ...          910.0      1965
# 4      8080     1.0         0.0   0.0  ...            0.0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0           0.0    98178  47.5112 -122.257           1340        5650
# 1        1991.0    98125  47.7210 -122.319           1690        7639
# 2           NaN    98028  47.7379 -122.233           2720        8062
# 3           0.0    98136  47.5208 -122.393           1360        5000
# 4           0.0    98074  47.6168 -122.045           1800        7503
#
#    year_sold  age
# 0       2014   59
# 1       2014   63
# 2       2015   82
# 3       2014   49
# 4       2015   28
#
# [5 rows x 23 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 23 columns):
# id               21143 non-null int64
# date             21143 non-null object
# price            21143 non-null float64
# bedrooms         21143 non-null float64
# bathrooms        21143 non-null float64
# sqft_living      21143 non-null int64
# sqft_lot         21143 non-null int64
# floors           21143 non-null float64
# waterfront       18804 non-null float64
# view             21082 non-null float64
# condition        21143 non-null int64
# grade            21143 non-null int64
# sqft_above       21143 non-null int64
# sqft_basement    21143 non-null float64
# yr_built         21143 non-null int64
# yr_renovated     17389 non-null float64
# zipcode          21143 non-null int64
# lat              21143 non-null float64
# long             21143 non-null float64
# sqft_living15    21143 non-null int64
# sqft_lot15       21143 non-null int64
# year_sold        21143 non-null int64
# age              21143 non-null int64
# dtypes: float64(10), int64(12), object(1)
# memory usage: 3.9+ MB

# %%
import statsmodels.api as sm

data = df1.loc[:,['price', 'sqft_living', 'grade', 'age', 'lat', 'long']]
x = data.drop('price', axis=1)
y = data['price']
x = sm.add_constant(x)
model_sm = sm.OLS(y,x)
results = model_sm.fit()
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.64
# const         -4.265317e+07
# sqft_living    1.909689e+02
# grade          1.230318e+05
# age            2.803586e+03
# lat            5.218721e+05
# long          -1.383828e+05
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     7638.
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:46:12   Log-Likelihood:            -2.9006e+05
# No. Observations:               21143   AIC:                         5.801e+05
# Df Residuals:                   21137   BIC:                         5.802e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -4.265e+07   1.52e+06    -28.109      0.000   -4.56e+07   -3.97e+07
# sqft_living   190.9689      2.586     73.835      0.000     185.899     196.039
# grade         1.23e+05   2158.877     56.989      0.000    1.19e+05    1.27e+05
# age          2803.5860     63.313     44.281      0.000    2679.488    2927.684
# lat          5.219e+05   1.13e+04     46.106      0.000       5e+05    5.44e+05
# long        -1.384e+05    1.2e+04    -11.546      0.000   -1.62e+05   -1.15e+05
# ==============================================================================
# Omnibus:                    19086.536   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1847184.806
# Skew:                           3.968   Prob(JB):                         0.00
# Kurtosis:                      48.098   Cond. No.                     2.29e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.29e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df1['logprice'] = np.log(df1['price'])
df1.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0       3.0       1.00         1180
# 1  6414100192   12/9/2014  538000.0       3.0       2.25         2570
# 2  5631500400   2/25/2015  180000.0       2.0       1.00          770
# 3  2487200875   12/9/2014  604000.0       4.0       3.00         1960
# 4  1954400510   2/18/2015  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0         NaN   0.0  ...      1955           0.0    98178
# 1      7242     2.0         0.0   0.0  ...      1951        1991.0    98125
# 2     10000     1.0         0.0   0.0  ...      1933           NaN    98028
# 3      5000     1.0         0.0   0.0  ...      1965           0.0    98136
# 4      8080     1.0         0.0   0.0  ...      1987           0.0    98074
#
#        lat     long  sqft_living15  sqft_lot15  year_sold  age   logprice
# 0  47.5112 -122.257           1340        5650       2014   59  12.309982
# 1  47.7210 -122.319           1690        7639       2014   63  13.195614
# 2  47.7379 -122.233           2720        8062       2015   82  12.100712
# 3  47.5208 -122.393           1360        5000       2014   49  13.311329
# 4  47.6168 -122.045           1800        7503       2015   28  13.142166
#
# [5 rows x 24 columns]

# %%
df1.age.unique()
# Out:
# array([ 59,  63,  82,  49,  28,  13,  52,  55,  12,  50,  72,  87,  37,
#        115,  36,  20,  98,  46,  67,  19,  29,  73,  99, 105,  66,  10,
#         11,   9,  85,  33,  84,  81, 110,  18,  14,  30,  92,  62,  64,
#         34,  88,   6,  24,  60,  41,   0,  35,  89,  25,  43,  58,  74,
#         22,  51,  53,   8,  26,  75,  68,  48,  39, 104,  31,   4,  69,
#         65,  90,  27, 101,  47,  54, 109,   7,  61,  15,  38,  16, 113,
#         21, 114,  94,  45, 100, 111,  96,  97,  86, 103,  78,  77,  76,
#        107,  40,  57, 102,  93,  17,  71,   1,  23,  91,  42,  95,   2,
#         32,   3,  56,  70,  44, 112,   5,  80,  83, 106, 108,  79,  -1])

# %% [markdown]
# since we notice that there is a negative value in age we will get exclude them from the model and carry out linear regression

# %%
# Normalised price with different predictors


df1 = df1[df1.age != -1]

data = df1.loc[:,['logprice', 'sqft_living','grade', 'age','lat']]
x = data.drop('logprice', axis=1)
y = data['logprice']
x = sm.add_constant(x)
model_sm = sm.OLS(y,x)
results = model_sm.fit()
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.73
# const         -52.0804
# sqft_living     0.0002
# grade           0.2014
# age             0.0035
# lat             1.3238
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logprice   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                 1.449e+04
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        12:46:27   Log-Likelihood:                -2490.8
# No. Observations:               21132   AIC:                             4992.
# Df Residuals:                   21127   BIC:                             5031.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -52.0804      0.661    -78.757      0.000     -53.377     -50.784
# sqft_living     0.0002   3.17e-06     71.937      0.000       0.000       0.000
# grade           0.2014      0.003     75.593      0.000       0.196       0.207
# age             0.0035   7.35e-05     47.925      0.000       0.003       0.004
# lat             1.3238      0.014     94.658      0.000       1.296       1.351
# ==============================================================================
# Omnibus:                      469.835   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1024.992
# Skew:                           0.078   Prob(JB):                    2.67e-223
# Kurtosis:                       4.068   Cond. No.                     8.04e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.04e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21132 entries, 0 to 21596
# Data columns (total 24 columns):
# id               21132 non-null int64
# date             21132 non-null object
# price            21132 non-null float64
# bedrooms         21132 non-null float64
# bathrooms        21132 non-null float64
# sqft_living      21132 non-null int64
# sqft_lot         21132 non-null int64
# floors           21132 non-null float64
# waterfront       18795 non-null float64
# view             21071 non-null float64
# condition        21132 non-null int64
# grade            21132 non-null int64
# sqft_above       21132 non-null int64
# sqft_basement    21132 non-null float64
# yr_built         21132 non-null int64
# yr_renovated     17383 non-null float64
# zipcode          21132 non-null int64
# lat              21132 non-null float64
# long             21132 non-null float64
# sqft_living15    21132 non-null int64
# sqft_lot15       21132 non-null int64
# year_sold        21132 non-null int64
# age              21132 non-null int64
# logprice         21132 non-null float64
# dtypes: float64(11), int64(12), object(1)
# memory usage: 4.0+ MB

# %% [markdown]
# **--------------------------------------------------------------------------------------------------------------**

# %%
df1.yr_renovated.fillna(0, inplace=True)
df1.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0       3.0       1.00         1180
# 1  6414100192   12/9/2014  538000.0       3.0       2.25         2570
# 2  5631500400   2/25/2015  180000.0       2.0       1.00          770
# 3  2487200875   12/9/2014  604000.0       4.0       3.00         1960
# 4  1954400510   2/18/2015  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0         NaN   0.0  ...      1955           0.0    98178
# 1      7242     2.0         0.0   0.0  ...      1951        1991.0    98125
# 2     10000     1.0         0.0   0.0  ...      1933           0.0    98028
# 3      5000     1.0         0.0   0.0  ...      1965           0.0    98136
# 4      8080     1.0         0.0   0.0  ...      1987           0.0    98074
#
#        lat     long  sqft_living15  sqft_lot15  year_sold  age   logprice
# 0  47.5112 -122.257           1340        5650       2014   59  12.309982
# 1  47.7210 -122.319           1690        7639       2014   63  13.195614
# 2  47.7379 -122.233           2720        8062       2015   82  12.100712
# 3  47.5208 -122.393           1360        5000       2014   49  13.311329
# 4  47.6168 -122.045           1800        7503       2015   28  13.142166
#
# [5 rows x 24 columns]

# %%
df1[df1.yr_renovated > 0] = df1[df1.yr_renovated > 0].assign(age = lambda x: x['year_sold'] - x['yr_renovated'])

# %%
df1.sample(20)
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 2608   1422300160   6/24/2014  379000.0       3.0       2.50         1740
# 16394  8562750660    8/7/2014  598500.0       4.0       2.50         2520
# 5405   3625059071    1/8/2015  899000.0       4.0       2.25         2290
# 17111  8100000080   8/13/2014  224400.0       3.0       1.75         1070
# 15548  5042300095  10/31/2014  730000.0       4.0       1.00         1870
# 15721  2545900050    5/9/2014  234950.0       3.0       1.00         1360
# 19485  3878900464    5/4/2015  229500.0       2.0       1.75         1870
# 15126  2722059215    6/3/2014  239000.0       3.0       1.75         1340
# 10610  8649900160   12/5/2014  692500.0       4.0       3.00         2820
# 9652   4137010530    5/4/2014  331950.0       4.0       2.50         2530
# 368     424069250   4/23/2015  785000.0       4.0       2.75         2440
# 9099   7338400945   2/24/2015  420000.0       3.0       1.50         2080
# 4283   8902000068   5/15/2014  430000.0       3.0       2.00         1510
# 8204   7227500450    9/9/2014  222900.0       2.0       1.00          860
# 6260   3990200020    9/8/2014  359000.0       4.0       1.75         1680
# 12318  5126900200   4/29/2015  162248.0       2.0       1.00          800
# 1503   8581200030   2/24/2015  230000.0       4.0       2.00         1220
# 18873  8910500237   7/26/2014  350000.0       3.0       3.25         1210
# 798    7852020640  10/20/2014  470000.0       3.0       2.50         2100
# 5250   1245003375    4/8/2015  658000.0       3.0       1.00         1290
#
#        sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  \
# 2608      30886     2.0         0.0   0.0  ...      1992           0.0
# 16394      3980     2.0         0.0   0.0  ...      2005           0.0
# 5405      40946     1.0         0.0   3.0  ...      1960           0.0
# 17111      7200     1.0         0.0   0.0  ...      1994           0.0
# 15548      4992     1.5         0.0   0.0  ...      1940           0.0
# 15721      9948     1.0         0.0   0.0  ...      1977           0.0
# 19485      6625     1.0         0.0   0.0  ...      1948           0.0
# 15126     16480     1.0         0.0   0.0  ...      1968           0.0
# 10610     11500     2.0         0.0   0.0  ...      1991           0.0
# 9652       9933     2.0         0.0   2.0  ...      1990           0.0
# 368       69415     1.0         0.0   0.0  ...      1989           0.0
# 9099       5000     1.0         0.0   0.0  ...      1963           0.0
# 4283       7066     1.0         0.0   2.0  ...      1973           0.0
# 8204       5800     1.0         0.0   0.0  ...      1942           0.0
# 6260       9244     2.0         0.0   0.0  ...      1991           0.0
# 12318      8960     1.0         0.0   0.0  ...      1944           0.0
# 1503       9100     1.5         0.0   0.0  ...      1970           0.0
# 18873       941     2.0         0.0   0.0  ...      2002           0.0
# 798        4700     2.0         0.0   0.0  ...      1999           0.0
# 5250      12005     1.0         0.0   0.0  ...      1966           0.0
#
#        zipcode      lat     long  sqft_living15  sqft_lot15  year_sold   age  \
# 2608     98045  47.4600 -121.707           1740       39133       2014  22.0
# 16394    98027  47.5401 -122.070           2610        3980       2014   9.0
# 5405     98008  47.6160 -122.103           2790       20076       2015  55.0
# 17111    98010  47.3129 -122.023           1280        7200       2014  20.0
# 15548    98199  47.6437 -122.396           2160        5239       2014  74.0
# 15721    98010  47.3422 -122.053           1670        8475       2014  37.0
# 19485    98178  47.5071 -122.249           1680        6000       2015  67.0
# 15126    98042  47.3640 -122.162           1520       10451       2014  46.0
# 10610    98075  47.5826 -122.028           2770        9694       2014  23.0
# 9652     98092  47.2654 -122.216           2140        9933       2014  24.0
# 368      98075  47.5944 -122.042           2770       24361       2015  26.0
# 9099     98118  47.5322 -122.290           1860        5000       2015  52.0
# 4283     98125  47.7053 -122.303           1950        8089       2014  41.0
# 8204     98056  47.4979 -122.183            900        6000       2014  72.0
# 6260     98166  47.4612 -122.352           1840        9387       2014  23.0
# 12318    98058  47.4756 -122.174            850        8082       2015  71.0
# 1503     98023  47.2964 -122.376           1160        7700       2015  45.0
# 18873    98133  47.7114 -122.356           1650        1493       2014  12.0
# 798      98065  47.5341 -121.867           2100        4700       2014  15.0
# 5250     98033  47.6835 -122.199           1930        8000       2015  49.0
#
#         logprice
# 2608   12.845291
# 16394  13.302182
# 5405   13.709038
# 17111  12.321185
# 15548  13.500800
# 15721  12.367128
# 19485  12.343658
# 15126  12.384219
# 10610  13.448064
# 9652   12.712740
# 368    13.573439
# 9099   12.948010
# 4283   12.971540
# 8204   12.314479
# 6260   12.791078
# 12318  11.996881
# 1503   12.345835
# 18873  12.765688
# 798    13.060488
# 5250   13.396960
#
# [20 rows x 24 columns]

# %%
# Unchanged price with different predictors


data = df1.loc[:,['logprice', 'sqft_living', 'grade','age','lat']]
x = data.drop('logprice', axis=1)
y = data['logprice']
x = sm.add_constant(x)
model_sm = sm.OLS(y,x)
results = model_sm.fit()
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.72
# const         -53.4901
# sqft_living     0.0002
# grade           0.1932
# age             0.0030
# lat             1.3552
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logprice   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                 1.387e+04
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        10:16:27   Log-Likelihood:                -2826.7
# No. Observations:               21132   AIC:                             5663.
# Df Residuals:                   21127   BIC:                             5703.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -53.4901      0.670    -79.811      0.000     -54.804     -52.176
# sqft_living     0.0002   3.21e-06     72.099      0.000       0.000       0.000
# grade           0.1932      0.003     71.546      0.000       0.188       0.198
# age             0.0030   7.59e-05     39.546      0.000       0.003       0.003
# lat             1.3552      0.014     95.629      0.000       1.327       1.383
# ==============================================================================
# Omnibus:                      520.327   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1057.144
# Skew:                           0.152   Prob(JB):                    2.78e-230
# Kurtosis:                       4.053   Cond. No.                     8.02e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.02e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------**

# %% [markdown]
# We will do some more analysis by creating subsets of data to understand granular relationshiops, we begin by checkling how the correlation changes based on number of floors and grade/condition of property.

# %%
df1.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'year_sold', 'age',
#        'logprice'],
#       dtype='object')

# %%
df2 = df1.loc[:,['price','grade', 'age', 'sqft_living','sqft_living15','lat', 'logprice', 'bedrooms', 'bathrooms']]

# %%
corrm = df2.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrm, vmin= -1, vmax= 1, square=True, annot = True);

# %%
data = df2.loc[:,['price', 'sqft_living', 'sqft_living15','age','lat']]
x = data.drop('price', axis=1)
y = data['price']
x = sm.add_constant(x)
model_sm = sm.OLS(y,x)
results = model_sm.fit()
r2 = results.rsquared
r2 = r2.round(2)
print('R2 = {}'.format(r2))
est_b = results.params
print(est_b.round(4))
results.summary()
# Out:
# R2 = 0.59
# const           -3.163000e+07
# sqft_living      2.504122e+02
# sqft_living15    7.667570e+01
# age              1.627585e+03
# lat              6.608397e+05
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.586
# Model:                            OLS   Adj. R-squared:                  0.586
# Method:                 Least Squares   F-statistic:                     7491.
# Date:                Tue, 22 Oct 2019   Prob (F-statistic):               0.00
# Time:                        11:37:19   Log-Likelihood:            -2.9149e+05
# No. Observations:               21132   AIC:                         5.830e+05
# Df Residuals:                   21127   BIC:                         5.830e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -3.163e+07   5.67e+05    -55.794      0.000   -3.27e+07   -3.05e+07
# sqft_living     250.4122      2.747     91.170      0.000     245.029     255.796
# sqft_living15    76.6757      3.656     20.972      0.000      69.510      83.842
# age            1627.5853     61.179     26.603      0.000    1507.669    1747.502
# lat            6.608e+05   1.19e+04     55.351      0.000    6.37e+05    6.84e+05
# ==============================================================================
# Omnibus:                    17538.473   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1190434.863
# Skew:                           3.566   Prob(JB):                         0.00
# Kurtosis:                      39.071   Cond. No.                     1.07e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
duplicated = df[df.duplicated(['id','price'])]
df[df.id == 1825069031]
# Out:
#               id        date     price  bedrooms  bathrooms  sqft_living  \
# 3946  1825069031   8/14/2014  550000.0         4       1.75         2410
# 3947  1825069031  10/16/2014  550000.0         4       1.75         2410
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 3946      8447     2.0         0.0   3.0  ...      8        2060
# 3947      8447     2.0         NaN   3.0  ...      8        2060
#
#       sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 3946          350.0     1936        1980.0    98074  47.6499 -122.088
# 3947          350.0     1936        1980.0    98074  47.6499 -122.088
#
#       sqft_living15  sqft_lot15
# 3946           2520       14789
# 3947           2520       14789
#
# [2 rows x 21 columns]

# %%
df.id.nunique()
# Out:
# 21420

# %%
for col in df.columns:
    print('{} has'.format(col), df[col].nunique())
# Out:
# id has 21420
# date has 372
# price has 3622
# bedrooms has 12
# bathrooms has 29
# sqft_living has 1034
# sqft_lot has 9776
# floors has 6
# waterfront has 2
# view has 5
# condition has 5
# grade has 11
# sqft_above has 942
# sqft_basement has 304
# yr_built has 116
# yr_renovated has 70
# zipcode has 70
# lat has 5033
# long has 751
# sqft_living15 has 777
# sqft_lot15 has 8682

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sqft_repeating = sorted(list(df.sqft_living.value_counts().head(25).index))
columns = ['bedrooms', 'bathrooms', 'age',
       'sqft_lot', 'floors', 'condition', 'grade',
       'sqft_above','lat']
for elem in sqft_repeating:
    for col in columns:
        print('for {}, the corr between price and {} is'.format(elem, col), df1[df1.sqft_living == elem].corr()['price'][col])
    print('\n')
# Out:
# for 1010, the corr between price and bedrooms is -0.22680645754800888
# for 1010, the corr between price and bathrooms is 0.13183499003075444
# for 1010, the corr between price and age is 0.39619941361189376
# for 1010, the corr between price and sqft_lot is -0.29968775389795016
# for 1010, the corr between price and floors is 0.1293227875715002
# for 1010, the corr between price and condition is -0.06277058377639134
# for 1010, the corr between price and grade is 0.12970244946020273
# for 1010, the corr between price and sqft_above is -0.13378918024067535
# for 1010, the corr between price and lat is 0.5360527315137504
#
#
# for 1200, the corr between price and bedrooms is -0.2420510959287156
# for 1200, the corr between price and bathrooms is 0.18630892676344724
# for 1200, the corr between price and age is 0.10446958376472187
# for 1200, the corr between price and sqft_lot is -0.23281219382146287
# for 1200, the corr between price and floors is 0.14248218141290142
# for 1200, the corr between price and condition is -0.05237826845552495
# for 1200, the corr between price and grade is 0.3475325754415572
# for 1200, the corr between price and sqft_above is -0.37480456880606455
# for 1200, the corr between price and lat is 0.6620353552694748
#
#
# for 1250, the corr between price and bedrooms is -0.12444199696564569
# for 1250, the corr between price and bathrooms is 0.15602743113872466
# for 1250, the corr between price and age is 0.25805273026746234
# for 1250, the corr between price and sqft_lot is -0.014318673171856755
# for 1250, the corr between price and floors is 0.1290423569372441
# for 1250, the corr between price and condition is 0.07775473169399731
# for 1250, the corr between price and grade is 0.14804868740458552
# for 1250, the corr between price and sqft_above is -0.22005381677616265
# for 1250, the corr between price and lat is 0.5784270903085841
#
#
# for 1300, the corr between price and bedrooms is -0.15491854265649874
# for 1300, the corr between price and bathrooms is 0.22057874912455694
# for 1300, the corr between price and age is 0.143751943771211
# for 1300, the corr between price and sqft_lot is 0.18567862754997402
# for 1300, the corr between price and floors is 0.29339217677178636
# for 1300, the corr between price and condition is -0.053496577825028084
# for 1300, the corr between price and grade is 0.32068258233779673
# for 1300, the corr between price and sqft_above is -0.005100500825544221
# for 1300, the corr between price and lat is 0.5540122855042174
#
#
# for 1320, the corr between price and bedrooms is -0.09029797102918974
# for 1320, the corr between price and bathrooms is 0.09574251920318626
# for 1320, the corr between price and age is 0.09827427652289898
# for 1320, the corr between price and sqft_lot is -0.1712500811814141
# for 1320, the corr between price and floors is 0.19009574136524549
# for 1320, the corr between price and condition is 0.1287493012193628
# for 1320, the corr between price and grade is 0.3090441895614111
# for 1320, the corr between price and sqft_above is -0.05564645525340728
# for 1320, the corr between price and lat is 0.5321667774372489
#
#
# for 1370, the corr between price and bedrooms is -0.24984101924310625
# for 1370, the corr between price and bathrooms is 0.04600366390783462
# for 1370, the corr between price and age is 0.18702608335232251
# for 1370, the corr between price and sqft_lot is -0.14016352849347138
# for 1370, the corr between price and floors is 0.22632967888483002
# for 1370, the corr between price and condition is -0.0467798154502088
# for 1370, the corr between price and grade is 0.41226119104883063
# for 1370, the corr between price and sqft_above is -0.22656526826141918
# for 1370, the corr between price and lat is 0.5551919831593379
#
#
# for 1400, the corr between price and bedrooms is -0.09301793057037105
# for 1400, the corr between price and bathrooms is 0.10876352026907789
# for 1400, the corr between price and age is 0.21394902555767137
# for 1400, the corr between price and sqft_lot is -0.09941110428882488
# for 1400, the corr between price and floors is 0.24225719114380126
# for 1400, the corr between price and condition is -0.018400976691324622
# for 1400, the corr between price and grade is 0.3054360915689172
# for 1400, the corr between price and sqft_above is -0.02976304178523425
# for 1400, the corr between price and lat is 0.5334326014386355
#
#
# for 1430, the corr between price and bedrooms is 0.042611723279221664
# for 1430, the corr between price and bathrooms is 0.03435053076744901
# for 1430, the corr between price and age is 0.1947092637047953
# for 1430, the corr between price and sqft_lot is -0.036944452242323955
# for 1430, the corr between price and floors is 0.20092578294890592
# for 1430, the corr between price and condition is -0.0022099265037157506
# for 1430, the corr between price and grade is 0.3715654634574416
# for 1430, the corr between price and sqft_above is 0.18248257406329718
# for 1430, the corr between price and lat is 0.610560823338464
#
#
# for 1440, the corr between price and bedrooms is -0.1558924177516725
# for 1440, the corr between price and bathrooms is -0.21898039642986855
# for 1440, the corr between price and age is 0.1888911879886681
# for 1440, the corr between price and sqft_lot is 0.11665378661630225
# for 1440, the corr between price and floors is 0.10945721380273749
# for 1440, the corr between price and condition is 0.02185262810522549
# for 1440, the corr between price and grade is 0.29600294778870334
# for 1440, the corr between price and sqft_above is 0.03981344096990907
# for 1440, the corr between price and lat is 0.5712504114680181
#
#
# for 1460, the corr between price and bedrooms is -0.29621354010634915
# for 1460, the corr between price and bathrooms is 0.29165656948701957
# for 1460, the corr between price and age is 0.13395985274578548
# for 1460, the corr between price and sqft_lot is -0.026216521770837768
# for 1460, the corr between price and floors is 0.2842093485823315
# for 1460, the corr between price and condition is 0.22876219064889405
# for 1460, the corr between price and grade is 0.33336604644679574
# for 1460, the corr between price and sqft_above is -0.19788158200823505
# for 1460, the corr between price and lat is 0.5949564058176533
#
#
# for 1480, the corr between price and bedrooms is 0.012905999327366156
# for 1480, the corr between price and bathrooms is 0.0008537676784417743
# for 1480, the corr between price and age is 0.15615509135806355
# for 1480, the corr between price and sqft_lot is 0.05325568646630521
# for 1480, the corr between price and floors is 0.2517097254388721
# for 1480, the corr between price and condition is -0.06532083522504907
# for 1480, the corr between price and grade is 0.2517278473802034
# for 1480, the corr between price and sqft_above is 0.12142302803249236
# for 1480, the corr between price and lat is 0.5460313919408984
#
#
# for 1540, the corr between price and bedrooms is -0.16406403520609164
# for 1540, the corr between price and bathrooms is 0.06382771294078696
# for 1540, the corr between price and age is 0.22956129056728503
# for 1540, the corr between price and sqft_lot is 0.1157354011164181
# for 1540, the corr between price and floors is 0.3244172896083828
# for 1540, the corr between price and condition is -0.11128676139883603
# for 1540, the corr between price and grade is 0.3669288231072265
# for 1540, the corr between price and sqft_above is 0.11266309925674606
# for 1540, the corr between price and lat is 0.5223859562025176
#
#
# for 1560, the corr between price and bedrooms is -0.05233465393270919
# for 1560, the corr between price and bathrooms is -0.04561705529125057
# for 1560, the corr between price and age is 0.260871556280246
# for 1560, the corr between price and sqft_lot is 0.002652121658488782
# for 1560, the corr between price and floors is -0.001997908854011888
# for 1560, the corr between price and condition is 0.1498735697086811
# for 1560, the corr between price and grade is 0.14149715074642494
# for 1560, the corr between price and sqft_above is -0.07540655995906677
# for 1560, the corr between price and lat is 0.5163174881094018
#
#
# for 1580, the corr between price and bedrooms is -0.20853833714851563
# for 1580, the corr between price and bathrooms is -0.08547229746564046
# for 1580, the corr between price and age is 0.1867051903301057
# for 1580, the corr between price and sqft_lot is -0.010145515982547182
# for 1580, the corr between price and floors is 0.18617232647725215
# for 1580, the corr between price and condition is -0.07370407609577027
# for 1580, the corr between price and grade is 0.46347140536821435
# for 1580, the corr between price and sqft_above is 0.014058959358873855
# for 1580, the corr between price and lat is 0.616706009413989
#
#
# for 1650, the corr between price and bedrooms is -0.08355854660229389
# for 1650, the corr between price and bathrooms is -0.15781624664315233
# for 1650, the corr between price and age is 0.3280064423443787
# for 1650, the corr between price and sqft_lot is 0.09001121310681717
# for 1650, the corr between price and floors is 0.1689534985158623
# for 1650, the corr between price and condition is 0.13796126780220044
# for 1650, the corr between price and grade is 0.3354683177860514
# for 1650, the corr between price and sqft_above is 0.08579065838113055
# for 1650, the corr between price and lat is 0.5253954299137502
#
#
# for 1660, the corr between price and bedrooms is -0.017848929313865794
# for 1660, the corr between price and bathrooms is 0.014128200419987908
# for 1660, the corr between price and age is 0.36654170194251506
# for 1660, the corr between price and sqft_lot is -0.2503669660121248
# for 1660, the corr between price and floors is 0.1525342769746618
# for 1660, the corr between price and condition is 0.12136331633370302
# for 1660, the corr between price and grade is 0.33538097601126005
# for 1660, the corr between price and sqft_above is -0.03660424945816577
# for 1660, the corr between price and lat is 0.6059619700477745
#
#
# for 1680, the corr between price and bedrooms is -0.1444595455547661
# for 1680, the corr between price and bathrooms is -0.006896875468210457
# for 1680, the corr between price and age is 0.08688605637338012
# for 1680, the corr between price and sqft_lot is -0.11468618169569106
# for 1680, the corr between price and floors is 0.1222648393156738
# for 1680, the corr between price and condition is 0.04175076226288601
# for 1680, the corr between price and grade is 0.36284557902419196
# for 1680, the corr between price and sqft_above is 0.029645577244464073
# for 1680, the corr between price and lat is 0.5764684146857642
#
#
# for 1720, the corr between price and bedrooms is -0.01089048793567318
# for 1720, the corr between price and bathrooms is -0.12815557709478867
# for 1720, the corr between price and age is 0.34673563589921197
# for 1720, the corr between price and sqft_lot is -0.045616800129987985
# for 1720, the corr between price and floors is 0.07449576766810309
# for 1720, the corr between price and condition is 0.027185423508703573
# for 1720, the corr between price and grade is 0.21716764796444082
# for 1720, the corr between price and sqft_above is -0.1294890234266246
# for 1720, the corr between price and lat is 0.6516545203679203
#
#
# for 1740, the corr between price and bedrooms is -0.12581864637506257
# for 1740, the corr between price and bathrooms is 0.057629487109926776
# for 1740, the corr between price and age is 0.10765405401774206
# for 1740, the corr between price and sqft_lot is -0.08752995584324302
# for 1740, the corr between price and floors is 0.24575668092779343
# for 1740, the corr between price and condition is 0.10059357683931427
# for 1740, the corr between price and grade is 0.5032626180291804
# for 1740, the corr between price and sqft_above is 0.18702544401240392
# for 1740, the corr between price and lat is 0.6219522148276407
#
#
# for 1780, the corr between price and bedrooms is -0.06255908107811381
# for 1780, the corr between price and bathrooms is 0.07823784338405054
# for 1780, the corr between price and age is 0.2510006141935902
# for 1780, the corr between price and sqft_lot is 0.016534208244776236
# for 1780, the corr between price and floors is 0.07364765327592378
# for 1780, the corr between price and condition is 0.2544416276583249
# for 1780, the corr between price and grade is 0.3732002903851683
# for 1780, the corr between price and sqft_above is 0.027907409718204056
# for 1780, the corr between price and lat is 0.519252730852063
#
#
# for 1800, the corr between price and bedrooms is -0.02541865848966274
# for 1800, the corr between price and bathrooms is -0.02551237339928654
# for 1800, the corr between price and age is 0.3967383514970121
# for 1800, the corr between price and sqft_lot is -0.08217465440969081
# for 1800, the corr between price and floors is -0.06690209648362701
# for 1800, the corr between price and condition is 0.15793009904322558
# for 1800, the corr between price and grade is 0.20939712549266376
# for 1800, the corr between price and sqft_above is -0.22478660322577987
# for 1800, the corr between price and lat is 0.5249221031253288
#
#
# for 1820, the corr between price and bedrooms is -0.16513718046043735
# for 1820, the corr between price and bathrooms is 0.07301032401314807
# for 1820, the corr between price and age is 0.21489612420252618
# for 1820, the corr between price and sqft_lot is 0.01457393308909313
# for 1820, the corr between price and floors is 0.12153828418270853
# for 1820, the corr between price and condition is 0.0031554184477966493
# for 1820, the corr between price and grade is 0.37766615817940796
# for 1820, the corr between price and sqft_above is 0.10468056839782852
# for 1820, the corr between price and lat is 0.491209577311738
#
#
# for 1830, the corr between price and bedrooms is -0.20974354773201143
# for 1830, the corr between price and bathrooms is -0.10508168420667745
# for 1830, the corr between price and age is 0.37277011792623344
# for 1830, the corr between price and sqft_lot is 0.022109610130678446
# for 1830, the corr between price and floors is -0.06699907171566141
# for 1830, the corr between price and condition is 0.1861675287469542
# for 1830, the corr between price and grade is 0.25603981919393276
# for 1830, the corr between price and sqft_above is -0.11720452233933615
# for 1830, the corr between price and lat is 0.5136766345313472
#
#
# for 1900, the corr between price and bedrooms is -0.08385504062821007
# for 1900, the corr between price and bathrooms is -0.014277147700149638
# for 1900, the corr between price and age is 0.18175185865484705
# for 1900, the corr between price and sqft_lot is -0.08338503344354958
# for 1900, the corr between price and floors is 0.01775708841014815
# for 1900, the corr between price and condition is 0.05473339198698225
# for 1900, the corr between price and grade is 0.286950557887701
# for 1900, the corr between price and sqft_above is -0.11195551236172367
# for 1900, the corr between price and lat is 0.5826692939003536
#
#
# for 2100, the corr between price and bedrooms is -0.13945688614805898
# for 2100, the corr between price and bathrooms is 0.025078190039733484
# for 2100, the corr between price and age is 0.23605250912044012
# for 2100, the corr between price and sqft_lot is -0.045478454943363875
# for 2100, the corr between price and floors is 0.014676030146851048
# for 2100, the corr between price and condition is 0.18426023540391562
# for 2100, the corr between price and grade is 0.28679088064292907
# for 2100, the corr between price and sqft_above is 0.08165050422231146
# for 2100, the corr between price and lat is 0.4643378803522614

# %%
sqft_repeating = list(df.sqft_living.value_counts().head(10).index)
for elem in sqft_repeating:
    plt.figure()
    plt.scatter(df[df.sqft_living == elem].lat, df[df.sqft_living == elem].price)
    plt.show()

# %%
sqft_repeating = list(df.sqft_living.value_counts().head(10).index)
for elem in sqft_repeating:
    plt.figure(figsize=(12, 8))
    sns.violinplot(y=df[df.sqft_living == elem].price,x= df[df.sqft_living == elem].lat)
    plt.show()

# %%
sqft_repeating = sorted(list(df.sqft_living.value_counts().head(10).index))
for elem in sqft_repeating:
    plt.figure()
    plt.scatter(df1[df1.sqft_living == elem].grade, df1[df1.sqft_living == elem].price)
    plt.show()

# %%
plt.scatter(df[df.sqft_living == 1540].lat, df[df.sqft_living == 1540].price)

# %%
df3 = df1.loc[:,:]
df3 = df3.assign( = lambda x: x[''] - x['yr_built'])

# %%
df[df.price == 350000]
corrm = df[df.price == 350000].corr()
f, ax = plt.subplots(figsize=(16,14))
sns.heatmap(corrm, vmin= -1, vmax= 1, square=True, annot = True);
